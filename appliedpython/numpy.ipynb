# %%
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------- ------------------------- 20.5/60.9 kB 54.8 kB/s eta 0:00:01
#      ------------- ------------------------- 20.5/60.9 kB 54.8 kB/s eta 0:00:01
#      ------------- ------------------------- 20.5/60.9 kB 54.8 kB/s eta 0:00:01
#      ------------------- ------------------- 30.7/60.9 kB 62.4 kB/s eta 0:00:01
# ...

# %%
import numpy as np
x=np.array([1, 2, 3, 4.4])  # Example usage of numpy
print(x)  # Output the numpy array
# Out:
# [1.  2.  3.  4.4]

# %%
x=np.array((1, 2, 3, 4.4))  # Example usage of numpy
print(x)  # Output the numpy array
# Out:
# [1.  2.  3.  4.4]

# %%
a=np .arange(5)
print(a)  # Output the array created using arange
# Out:
# [0 1 2 3 4]

# %%
a=np.array([1, 2, 3, 4.4])  # Example usage of numpy
