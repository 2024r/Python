# %%
import numpy as np
import pandas as pd

# %% [markdown]
# creating dataframes

# %%
data_sample =[
    [50,40,47],
    [70,73,75],
    [10,400,34],
    [20,30,25]
]
data1 = pd.DataFrame(data_sample, columns=['A', 'B', 'C'])
data1
# Out:
#     A    B   C
# 0  50   40  47
# 1  70   73  75
# 2  10  400  34
# 3  20   30  25

# %%
data_dict = {
    'col1':['name1', 'name2', 'name3', 'name4'],
    'col2':[1, 2, 3, 4],
    'col3':[10, 20, 30, 40],
    'col4':[100, 200, 300, 400]
}
student= pd.DataFrame(data_dict)

x = student.set_index('col1',inplace=True)
print(x)
print(student)
# Out:
# None
#        col2  col3  col4
# col1
# name1     1    10   100
# name2     2    20   200
# name3     3    30   300
# name4     4    40   400

# %%
#using read_csv
titanic = pd.read_csv('Titanic Dataset.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
weather = pd.read_csv('austin_weather.csv')
weather
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
#shape
print(titanic.shape)
print(weather.shape)
# Out:
# (418, 12)
# (1319, 21)

# %%
#dtypes
print(titanic.dtypes)  
print(weather.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# Date                          object
# TempHighF                      int64
# TempAvgF                       int64
# TempLowF                       int64
# DewPointHighF                 object
# DewPointAvgF                  object
# DewPointLowF                  object
# HumidityHighPercent           object
# HumidityAvgPercent            object
# HumidityLowPercent            object
# SeaLevelPressureHighInches    object
# SeaLevelPressureAvgInches     object
# SeaLevelPressureLowInches     object
# VisibilityHighMiles           object
# VisibilityAvgMiles            object
# VisibilityLowMiles            object
# WindHighMPH                   object
# ...

# %%
#index
print(titanic.index)
print(weather.index)    
print(student.index)
# Out:
# RangeIndex(start=0, stop=418, step=1)
# RangeIndex(start=0, stop=1319, step=1)
# Index(['name1', 'name2', 'name3', 'name4'], dtype='object', name='col1')

# %%
#columns
print(titanic.columns)
print(weather.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
#values
print(titanic.values)
# Out:
# [[892 0 3 ... 7.8292 nan 'Q']
#  [893 1 3 ... 7.0 nan 'S']
#  [894 0 2 ... 9.6875 nan 'Q']
#  ...
#  [1307 0 3 ... 7.25 nan 'S']
#  [1308 0 3 ... 8.05 nan 'S']
#  [1309 0 3 ... 22.3583 nan 'C']]

# %%
print(weather.values)
# Out:
# [['2013-12-21' 74 60 ... '31' '0.46' 'Rain , Thunderstorm']
#  ['2013-12-22' 56 48 ... '25' '0' ' ']
#  ['2013-12-23' 58 45 ... '12' '0' ' ']
#  ...
#  ['2017-07-29' 107 92 ... '17' '0' ' ']
#  ['2017-07-30' 106 93 ... '20' '0' ' ']
#  ['2017-07-31' 99 88 ... '20' '0' ' ']]

# %%
import pandas as pd
import numpy as np

# %%
#head and tail
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
titanic.tail(1)
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 417         1309         0       3  Peter, Master. Michael J  male  NaN
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 417      1      1   2668  22.3583   NaN        C

# %%
#sample
titanic.sample()
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 9          901         0       3  Davies, Mr. John Samuel  male  21.0      2
#
#    Parch     Ticket   Fare Cabin Embarked
# 9      0  A/4 48871  24.15   NaN        S

# %%
weather.sample()
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 1262  2017-06-05         90        78        66            70           68
#
#      DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 1262           65                 100                 72                 44
#
#       ... SeaLevelPressureAvgInches SeaLevelPressureLowInches  \
# 1262  ...                     29.74                     29.68
#
#      VisibilityHighMiles VisibilityAvgMiles VisibilityLowMiles WindHighMPH  \
# 1262                  10                  9                  0          25
#
#      WindAvgMPH WindGustMPH PrecipitationSumInches                     Events
# 1262          3          41                   1.39  Fog , Rain , Thunderstorm
#
# [1 rows x 21 columns]

# %%
#info
titanic.info()
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ...

# %%
#describe
titanic.describe()

# %%
weather.describe()
# Out:
#          TempHighF     TempAvgF     TempLowF
# count  1319.000000  1319.000000  1319.000000
# mean     80.862775    70.642911    59.902957
# std      14.766523    14.045904    14.190648
# min      32.000000    29.000000    19.000000
# 25%      72.000000    62.000000    49.000000
# 50%      83.000000    73.000000    63.000000
# 75%      92.000000    83.000000    73.000000
# max     107.000000    93.000000    81.000000

# %%
#isnull 
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#dublicates
print(titanic.duplicated().sum())
# Out:
# 0

# %%
x=student.rename(columns={'col1':'python', 'col2':'c++',}, inplace=True )
print(x)
# Out:
# None

# %% [markdown]
# math method

# %%
#sum -> axis argument
print(student.sum(axis=0))  # sum of each column
# Out:
# c++       10
# col3     100
# col4    1000
# dtype: int64

# %%
student.sum(axis=1)  # sum of each row
# Out:
# col1
# name1    111
# name2    222
# name3    333
# name4    444
# dtype: int64

# %%
#mean
student.mean(axis=0) # mean of each column
student.mean(axis=1)  # mean of each row
# Out:
# col1
# name1     37.0
# name2     74.0
# name3    111.0
# name4    148.0
# dtype: float64

# %%
#varience
student.var()  # variance of each column
# Out:
# col2        1.666667
# col3      166.666667
# col4    16666.666667
# dtype: float64

# %%
#standard deviation
student.std()  # standard deviation of each column
# Out:
# c++       1.290994
# col3     12.909944
# col4    129.099445
# dtype: float64

# %% [markdown]
# dataframes cols

# %%
#multiwether cols
titanic[['PassengerId', 'Survived', 'Pclass', ]]
# Out:
#      PassengerId  Survived  Pclass
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
# [418 rows x 3 columns]

# %%
weather[['Date', 'TempAvgF', 'Events']]
# Out:
#             Date  TempAvgF               Events
# 0     2013-12-21        60  Rain , Thunderstorm
# 1     2013-12-22        48
# 2     2013-12-23        45
# 3     2013-12-24        46
# 4     2013-12-25        50
# ...          ...       ...                  ...
# 1314  2017-07-27        89
# 1315  2017-07-28        91
# 1316  2017-07-29        92
# 1317  2017-07-30        93
# 1318  2017-07-31        88
#
# [1319 rows x 3 columns]

# %% [markdown]
# ROWS

# %%
#ACCESING SINGLE ROW
titanic.iloc[0]  # first row
titanic.iloc[1]  # second row
# Out:
# PassengerId                                 893
# Survived                                      1
# Pclass                                        3
# Name           Wilkes, Mrs. James (Ellen Needs)
# Sex                                      female
# Age                                        47.0
# SibSp                                         1
# Parch                                         0
# Ticket                                   363272
# Fare                                        7.0
# Cabin                                       NaN
# Embarked                                      S
# Name: 1, dtype: object

# %%
#ACCESING ROWS TOGETHER
titanic.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
student.iloc['name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 student.iloc['name']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# ...

# %%
titanic.iloc[0:5,0:7]  # first 5 rows and first 7 columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp
# 0                              Kelly, Mr. James    male  34.5      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3                              Wirz, Mr. Albert    male  27.0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1

# %%
titanic.iloc[0:0:2,'PassengerId','age']  # every second row in the first column
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 titanic.iloc[0:0:2,'PassengerId','age']  # every second row in the first column
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
# ...

# %%
#completelly new
titanic['country'] = 'India'  # adding a new column with a constant value
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 354         1246         1       3
# 132         1024         1       3
# 118         1010         0       1
# 140         1032         1       3
# 78           970         0       2
# 165         1057         1       3
# 195         1087         0       3
# 105          997         0       3
# 40           932         0       3
# 187         1079         0       3
#
#                                            Name     Sex    Age  SibSp  Parch  \
# 354     Dean, Miss. Elizabeth Gladys Millvina""  female   0.17      1      2
# 132               Lefebre, Mrs. Frank (Frances)  female    NaN      0      4
# 118                        Beattie, Mr. Thomson    male  36.00      0      0
# 140                 Goodwin, Miss. Jessie Allis  female  10.00      5      2
# 78               Aldworth, Mr. Charles Augustus    male  30.00      0      0
# 165  Kink-Heilmann, Mrs. Anton (Luise Heilmann)  female  26.00      1      1
# ...

# %%
#wap that will tale input faom the user and print the frist  or last name of the user
name = input("Enter your full name: ")
names = name.split()
if len(names) > 1:
    print("First Name:", names[0])
    print("Last Name:", names[-1])
# Out:
# First Name: ritesh
# Last Name: yadav

# %%
x=['how','are','you']
y=" ".join(x)  # joining list elements into a string
print(y)  # Output: "how are you"
# Out:
# how are you

# %%
name = input("Enter your full name: ")
#wap that will tale input faom the user and print the frist  or last name of the user
print("".join(name.split()[:-2]))#prints first and last name if available
# Out:
# ritesh

# %%
titanic['PassengerId']= titanic['PassengerId'].astypes('int32')  # converting PassengerId to int32 type

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
#  12  country      418 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 42.6+ KB

# %%
weather ['Events']= weather ['Events'].astype('category')  # converting Events to category type

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %% [markdown]
#  2.value count()

# %%
student
# Out:
#        col2  col3  col4
# col1
# name1     1    10   100
# name2     2    20   200
# name3     3    30   300
# name4     4    40   400

# %%
student.value_counts()
# Out:
# col2  col3  col4
# 1     10    100     1
# 2     20    200     1
# 3     30    300     1
# 4     40    400     1
# Name: count, dtype: int64

# %%
#find how many passengers are there in each class 
titanic['Pclass'].value_counts()  # counting the number of passengers in each class
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
weather['Events'].value_counts()  # counting the number of occurrences of each event in the weather dataset
# Out:
# Events
#                              903
# Rain                         192
# Rain , Thunderstorm          137
# Fog , Rain , Thunderstorm     33
# Fog                           21
# Thunderstorm                  17
# Fog , Rain                    14
# Fog , Thunderstorm             1
# Rain , Snow                    1
# Name: count, dtype: int64

# %%
((titanic['Age']>=40) & (titanic['Sex']=='male')).value_counts()  # counting the number
# Out:
# False    366
# True      52
# Name: count, dtype: int64

# %%
((titanic['SibSp']==0 ) & (titanic['Parch']==0)).value_counts()  # counting the number of siblings and parch in the titanic dataset
# Out:
# True     253
# False    165
# Name: count, dtype: int64

# %%
(titanic['Sex']=="male"&)

# %%
titanic
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
titanic
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
titanic
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
titanic.sort_index(['Pclass'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 titanic.sort_index(['Pclass'], ascending=False)
#
# TypeError: DataFrame.sort_index() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given

# %%
titanic.set_index(['PassangerId'], inplace=True)  # setting PassengerID as the index of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14104\3618853869.py in ?()
# ----> 1 titanic.set_index(['PassangerId'], inplace=True)  # setting PassengerID as the index of the DataFrame
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6125                     if not found:
#    6126                         missing.append(col)
#    6127
#    6128         if missing:
# -> 6129             raise KeyError(f"None of {missing} are in the columns")
#    6130
#    6131         if inplace:
#    6132             frame = self
#
# KeyError: "None of ['PassangerId'] are in the columns"

# %%
#converting series into datafraes 
marks={
    'maths':57,
    'science':65,   
    'english':75,
    'history':80
}

marks_series = pd.Series(marks)  # converting the dictionary to a Series
marks_series
# Out:
# maths      57
# science    65
# english    75
# history    80
# dtype: int64

# %% [markdown]
# fillna

# %%
new_data{'name'}=New_data = ['name']

# %% [markdown]
# 1. Display the names of all passengers who paid a fare greater than $100
# and were under the age of 30.

# %%
result = titanic[(titanic['Fare'] > 100) & (titanic['Age'] < 30)]
print(result['Name'])
# Out:
# PassengerId
# 945                            Fortune, Miss. Ethel Flora
# 956                           Ryerson, Master. John Borie
# 1048                                    Bird, Miss. Ellen
# 1076    Douglas, Mrs. Frederick Charles (Mary Helene B...
# 1088                      Spedden, Master. Robert Douglas
# 1144                             Clark, Mr. Walter Miller
# 1164        Clark, Mrs. Walter Miller (Virginia McDowell)
# Name: Name, dtype: object

# %% [markdown]
# 2. Find the top 5 oldest passengers. What are their names, ages, and
# whether they survived?

# %%
passengeroldest = titanic.sort_values('Age', ascending=False).head(5)
print(passengeroldest[['Name', 'Age', 'Survived']])
# Out:
#                                                           Name   Age  Survived
# PassengerId
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...  76.0         1
# 973                                         Straus, Mr. Isidor  67.0         0
# 1128                                  Warren, Mr. Frank Manley  64.0         0
# 1071         Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  64.0         1
# 1197         Crosby, Mrs. Edward Gifford (Catherine Elizabe...  64.0         1

# %% [markdown]
# 3. Count how many passengers have a missing value for their cabin
# number (Cabin).

# %%
missing = titanic['Cabin'].isnull().sum()
print(missing)
# Out:
# 327
